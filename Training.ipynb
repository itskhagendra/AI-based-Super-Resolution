# %%
import torch
from torch import optim,nn
from torchvision import transforms,datasets
import torch.nn.functional as F
import torch.nn.init as init
import matplotlib as plt
import torch.utils.data as data

import os
from os import listdir
from math import log10
from PIL import Image


# %matplotlib inline

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
def Downloaddata():
    import urllib
    #import wget
    path = "./"
    tgz_file = "BSDS300-images.tgz"
    print("Data Download Initialing...")
    url = "http://www2.eecs.berkeley.edu/Research/Projects/CS/vision/bsds/BSDS300-images.tgz"
    #wget.download(url)
    data = urllib.request.urlretrieve(url,tgz_file)
    print("Data Download Complete")
    print("Data Extraction Initializing...")
    with tarfile.open(tgz_file) as tar:
        for item in tar:
            tar.extract(item,path)
    print("Data Extraction Complete")

# %%
def dataset():
    data_dir = "BSDS300/images"
    if(not os.path.exists(data_dir)):
        Downloaddata()
    return data_dir

# %%
upscale_Factor = 3
batch_Size = 4
Learning_Rate = 0.001

# %%
def is_image_file(filename):
    return any(filename.endswith(extension) for extension in [".png",".jpg",".jpeg"])

def load_img(filepath):
    img = Image.open(filepath).convert('YCbCr')
    y,_,_ = img.split()
    return y

# %%
class DatasetFromFolder(data.Dataset):
    def __init__(self,img_dir,input_transform=None,target_transform=None):
        super(DatasetFromFolder,self).__init__()
        self.image_filenames = [img_dir+"/"+x for x in listdir(img_dir) if is_image_file(x)]
        
        self.input_transform = input_transform
        self.target_transform = target_transform
        
    
    
    def __getitem__(self,index):
        Input=load_img(self.image_filenames[index])
        target = Input.copy()
        if self.input_transform:
            Input = self.input_transform(Input)
            
        if self.target_transform:
            target = self.target_transform(target)
            
        return Input, target
    
    def __len__(self):
        return len(self.image_filenames)

# %%
def valid_crop_size(crop_size,upscale_factor):
    return crop_size - (crop_size % upscale_factor)

def input_transform(crop_size,upscale_factor):
    return transforms.Compose([transforms.CenterCrop(crop_size),
                               transforms.Resize(crop_size//upscale_factor),
                               transforms.ToTensor(),
                              ])

def target_transform(crop_size,upscale_factor):
    return transforms.Compose([transforms.CenterCrop(crop_size),
                               transforms.ToTensor(),
                              ])

def fetch_training_data(upscale_factor):
    dataset_dir = dataset()
    train_dir = dataset_dir+"/train/"
    crop_size = valid_crop_size(256,upscale_factor)
    
    return DatasetFromFolder(train_dir,
                             input_transform=input_transform(crop_size,upscale_factor),
                             target_transform=target_transform(crop_size,upscale_factor)
                            )

def fetch_test_Data(upscale_factor):
    datasetDir = dataset()
    test_dir = datasetDir+"/test"
    crop_size = valid_crop_size(256,upscale_factor)
    
    return DatasetFromFolder(test_dir,
                            input_transform = input_transform(crop_size,upscale_factor),
                            target_transform = target_transform(crop_size,upscale_factor)
                            )
def checkpoint(epoch):
    model_out_path = "model_epoch_{}.pth".format(epoch)
    torch.save(model,model_out_path)
    print("Checkpoint saved to {}".format(model_out_path))

# %%
train_data = fetch_training_data(upscale_Factor)
test_data = fetch_test_Data(upscale_Factor)

# %%
train_loader = torch.utils.data.DataLoader(train_data,batch_size=4,shuffle=True)
test_data = torch.utils.data.DataLoader(test_data,batch_size=4,shuffle=True)

# %%
class Model(nn.Module):
    def __init__(self):
        super(Model,self).__init__()
        self.relu = nn.ReLU()
        self.conv1 = nn.Conv2d(1,64,(5,5),(1,1),(2,2))
        self.conv2 = nn.Conv2d(64,64,(3,3),(1,1),(1,1))
        self.conv3 = nn.Conv2d(64,32,(3,3),(1,1),(1,1))
        self.conv4 = nn.Conv2d(32,3**2,(3,3),(1,1),(1,1))
        self.pixel_shuffle = nn.PixelShuffle(3)
        self._initialize_weights()
    
    def forward(self,x):
        x=self.relu(self.conv1(x))
        x=self.relu(self.conv2(x))
        x=self.relu(self.conv3(x))
        x=self.pixel_shuffle(self.conv4(x))
        
        return x
    
    def _initialize_weights(self):
        init.orthogonal_(self.conv1.weight, init.calculate_gain('relu'))
        init.orthogonal_(self.conv2.weight,init.calculate_gain('relu'))
        init.orthogonal_(self.conv3.weight,init.calculate_gain('relu'))
        init.orthogonal_(self.conv4.weight)

# %%
model = Model()
model
# Out:
# Model(
#   (relu): ReLU()
#   (conv1): Conv2d(1, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv4): Conv2d(32, 9, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pixel_shuffle): PixelShuffle(upscale_factor=3)
# )

# %%
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(),lr=Learning_Rate)

# %%
model.to(device)
epoch=500
train_loss = 0.0
valid_loss = 0.0
accuracy = 0.0

for i in range(epoch):
    model.train()
    for input_image,target_image  in enumerate(train_loader,1):
        input_image,target_image = target_image[0].to(device),target_image[1].to(device)
        
        optimizer.zero_grad()
        loss = criterion(model(input_image),target_image)
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item()
        
    for test_batch in test_data:
        input_image,target_image = test_batch[0].to(device),test_batch[1].to(device)
        output = model(input_image)
        loss = criterion(output,target_image)
        psnr = 10*log10(1/loss.item())
        valid_loss += psnr
        
    train_loss = train_loss/len(train_loader)
    valid_loss = valid_loss/len(test_data)
    accuracy = (valid_loss/40.0)*100
    print("Epoch {} \tTraining Loss: {:.4f} \tPSNR: {:.4f}\tAccuracy: {:.3f}%".format((i+1),train_loss,valid_loss,accuracy))
# Out:
# Epoch 1 	Training Loss: 0.0251 	PSNR: 20.4208	Accuracy: 51.052%
# Epoch 2 	Training Loss: 0.0074 	PSNR: 23.2980	Accuracy: 58.245%
# Epoch 3 	Training Loss: 0.0051 	PSNR: 24.3642	Accuracy: 60.910%
# Epoch 4 	Training Loss: 0.0043 	PSNR: 24.8232	Accuracy: 62.058%
# Epoch 5 	Training Loss: 0.0040 	PSNR: 24.8854	Accuracy: 62.213%
# Epoch 6 	Training Loss: 0.0038 	PSNR: 25.1964	Accuracy: 62.991%
# Epoch 7 	Training Loss: 0.0037 	PSNR: 25.3176	Accuracy: 63.294%
# Epoch 8 	Training Loss: 0.0036 	PSNR: 25.5771	Accuracy: 63.943%
# Epoch 9 	Training Loss: 0.0042 	PSNR: 23.4886	Accuracy: 58.721%
# Epoch 10 	Training Loss: 0.0045 	PSNR: 25.3841	Accuracy: 63.460%
# Epoch 11 	Training Loss: 0.0036 	PSNR: 25.5794	Accuracy: 63.949%
# Epoch 12 	Training Loss: 0.0035 	PSNR: 25.8045	Accuracy: 64.511%
# Epoch 13 	Training Loss: 0.0034 	PSNR: 25.5532	Accuracy: 63.883%
# Epoch 14 	Training Loss: 0.0034 	PSNR: 25.6897	Accuracy: 64.224%
# Epoch 15 	Training Loss: 0.0034 	PSNR: 25.7931	Accuracy: 64.483%
# Epoch 16 	Training Loss: 0.0034 	PSNR: 25.6682	Accuracy: 64.171%
# Epoch 17 	Training Loss: 0.0034 	PSNR: 25.7252	Accuracy: 64.313%
# Epoch 18 	Training Loss: 0.0034 	PSNR: 25.7595	Accuracy: 64.399%
# Epoch 53 	Training Loss: 0.0032 	PSNR: 25.9325	Accuracy: 64.831%
# Epoch 54 	Training Loss: 0.0032 	PSNR: 26.0097	Accuracy: 65.024%
# Epoch 55 	Training Loss: 0.0032 	PSNR: 26.0181	Accuracy: 65.045%
# Epoch 56 	Training Loss: 0.0031 	PSNR: 26.1350	Accuracy: 65.337%
# Epoch 57 	Training Loss: 0.0031 	PSNR: 25.8953	Accuracy: 64.738%
# Epoch 58 	Training Loss: 0.0031 	PSNR: 26.0181	Accuracy: 65.045%
# Epoch 59 	Training Loss: 0.0031 	PSNR: 25.9199	Accuracy: 64.800%
# Epoch 60 	Training Loss: 0.0032 	PSNR: 26.0264	Accuracy: 65.066%
# Epoch 61 	Training Loss: 0.0031 	PSNR: 26.0653	Accuracy: 65.163%
# Epoch 62 	Training Loss: 0.0031 	PSNR: 26.0920	Accuracy: 65.230%
# Epoch 63 	Training Loss: 0.0031 	PSNR: 26.1137	Accuracy: 65.284%
# Epoch 64 	Training Loss: 0.0031 	PSNR: 25.7770	Accuracy: 64.443%
# Epoch 65 	Training Loss: 0.0031 	PSNR: 26.0414	Accuracy: 65.103%
# Epoch 66 	Training Loss: 0.0031 	PSNR: 25.9925	Accuracy: 64.981%
# Epoch 67 	Training Loss: 0.0031 	PSNR: 25.9001	Accuracy: 64.750%
# Epoch 68 	Training Loss: 0.0031 	PSNR: 26.0553	Accuracy: 65.138%
# Epoch 69 	Training Loss: 0.0032 	PSNR: 26.1130	Accuracy: 65.283%
# Epoch 70 	Training Loss: 0.0031 	PSNR: 25.8500	Accuracy: 64.625%
# Epoch 71 	Training Loss: 0.0035 	PSNR: 25.6051	Accuracy: 64.013%
# Epoch 72 	Training Loss: 0.0033 	PSNR: 26.1702	Accuracy: 65.426%
# Epoch 73 	Training Loss: 0.0031 	PSNR: 25.9851	Accuracy: 64.963%
# Epoch 74 	Training Loss: 0.0031 	PSNR: 26.0202	Accuracy: 65.050%
# Epoch 75 	Training Loss: 0.0031 	PSNR: 26.0054	Accuracy: 65.013%
# Epoch 76 	Training Loss: 0.0031 	PSNR: 26.1006	Accuracy: 65.252%
# Epoch 77 	Training Loss: 0.0031 	PSNR: 25.9510	Accuracy: 64.877%
# Epoch 78 	Training Loss: 0.0031 	PSNR: 26.0274	Accuracy: 65.068%
# Epoch 79 	Training Loss: 0.0031 	PSNR: 26.1854	Accuracy: 65.464%
# Epoch 80 	Training Loss: 0.0031 	PSNR: 26.2301	Accuracy: 65.575%
# Epoch 81 	Training Loss: 0.0031 	PSNR: 25.9850	Accuracy: 64.962%
# Epoch 82 	Training Loss: 0.0031 	PSNR: 26.1280	Accuracy: 65.320%
# Epoch 83 	Training Loss: 0.0031 	PSNR: 26.1004	Accuracy: 65.251%
# Epoch 84 	Training Loss: 0.0031 	PSNR: 26.2327	Accuracy: 65.582%
# Epoch 85 	Training Loss: 0.0031 	PSNR: 26.1294	Accuracy: 65.324%
# Epoch 86 	Training Loss: 0.0031 	PSNR: 26.0536	Accuracy: 65.134%
# Epoch 87 	Training Loss: 0.0031 	PSNR: 26.1118	Accuracy: 65.280%
# Epoch 192 	Training Loss: 0.0029 	PSNR: 26.2232	Accuracy: 65.558%
# Epoch 193 	Training Loss: 0.0029 	PSNR: 26.2152	Accuracy: 65.538%
# Epoch 194 	Training Loss: 0.0029 	PSNR: 26.2381	Accuracy: 65.595%
# Epoch 195 	Training Loss: 0.0029 	PSNR: 26.1593	Accuracy: 65.398%
# Epoch 196 	Training Loss: 0.0029 	PSNR: 26.1563	Accuracy: 65.391%
# Epoch 197 	Training Loss: 0.0030 	PSNR: 26.1861	Accuracy: 65.465%
# Epoch 198 	Training Loss: 0.0029 	PSNR: 26.2317	Accuracy: 65.579%
# Epoch 199 	Training Loss: 0.0030 	PSNR: 25.9161	Accuracy: 64.790%
# Epoch 200 	Training Loss: 0.0030 	PSNR: 26.2339	Accuracy: 65.585%
# Epoch 201 	Training Loss: 0.0029 	PSNR: 26.2009	Accuracy: 65.502%
# Epoch 202 	Training Loss: 0.0029 	PSNR: 26.1945	Accuracy: 65.486%
# Epoch 203 	Training Loss: 0.0030 	PSNR: 26.2629	Accuracy: 65.657%
# Epoch 204 	Training Loss: 0.0029 	PSNR: 26.2510	Accuracy: 65.628%
# Epoch 205 	Training Loss: 0.0029 	PSNR: 26.2851	Accuracy: 65.713%
# Epoch 206 	Training Loss: 0.0030 	PSNR: 26.2979	Accuracy: 65.745%
# Epoch 207 	Training Loss: 0.0031 	PSNR: 26.0511	Accuracy: 65.128%
# Epoch 208 	Training Loss: 0.0030 	PSNR: 26.2138	Accuracy: 65.535%
# Epoch 209 	Training Loss: 0.0029 	PSNR: 26.0949	Accuracy: 65.237%
# Epoch 210 	Training Loss: 0.0029 	PSNR: 26.2845	Accuracy: 65.711%
# Epoch 211 	Training Loss: 0.0029 	PSNR: 26.2965	Accuracy: 65.741%
# Epoch 212 	Training Loss: 0.0029 	PSNR: 26.3402	Accuracy: 65.851%
# Epoch 213 	Training Loss: 0.0029 	PSNR: 26.2256	Accuracy: 65.564%
# Epoch 214 	Training Loss: 0.0029 	PSNR: 26.2388	Accuracy: 65.597%
# Epoch 215 	Training Loss: 0.0029 	PSNR: 26.3193	Accuracy: 65.798%
# Epoch 216 	Training Loss: 0.0029 	PSNR: 26.3594	Accuracy: 65.898%
# Epoch 217 	Training Loss: 0.0029 	PSNR: 26.2352	Accuracy: 65.588%
# Epoch 218 	Training Loss: 0.0029 	PSNR: 26.2088	Accuracy: 65.522%
# Epoch 219 	Training Loss: 0.0029 	PSNR: 26.2942	Accuracy: 65.735%
# Epoch 220 	Training Loss: 0.0033 	PSNR: 25.8849	Accuracy: 64.712%
# Epoch 221 	Training Loss: 0.0030 	PSNR: 26.0400	Accuracy: 65.100%
# Epoch 222 	Training Loss: 0.0029 	PSNR: 26.1808	Accuracy: 65.452%
# Epoch 223 	Training Loss: 0.0029 	PSNR: 26.1813	Accuracy: 65.453%
# Epoch 224 	Training Loss: 0.0029 	PSNR: 26.2778	Accuracy: 65.694%
# Epoch 225 	Training Loss: 0.0029 	PSNR: 26.3121	Accuracy: 65.780%
# Epoch 226 	Training Loss: 0.0029 	PSNR: 26.3448	Accuracy: 65.862%
# Epoch 227 	Training Loss: 0.0029 	PSNR: 26.2011	Accuracy: 65.503%
# Epoch 228 	Training Loss: 0.0029 	PSNR: 26.2877	Accuracy: 65.719%
# Epoch 229 	Training Loss: 0.0029 	PSNR: 26.2280	Accuracy: 65.570%
# Epoch 230 	Training Loss: 0.0029 	PSNR: 26.2231	Accuracy: 65.558%
# Epoch 231 	Training Loss: 0.0029 	PSNR: 26.2435	Accuracy: 65.609%
# Epoch 232 	Training Loss: 0.0029 	PSNR: 26.2072	Accuracy: 65.518%
# Epoch 233 	Training Loss: 0.0029 	PSNR: 26.2592	Accuracy: 65.648%
# Epoch 234 	Training Loss: 0.0029 	PSNR: 26.3390	Accuracy: 65.848%
# Epoch 235 	Training Loss: 0.0029 	PSNR: 26.4334	Accuracy: 66.084%
# Epoch 236 	Training Loss: 0.0029 	PSNR: 26.1836	Accuracy: 65.459%
# Epoch 237 	Training Loss: 0.0030 	PSNR: 26.1786	Accuracy: 65.447%
# Epoch 238 	Training Loss: 0.0029 	PSNR: 26.2583	Accuracy: 65.646%
# Epoch 239 	Training Loss: 0.0029 	PSNR: 26.2386	Accuracy: 65.597%
# Epoch 240 	Training Loss: 0.0029 	PSNR: 26.2778	Accuracy: 65.695%
# Epoch 241 	Training Loss: 0.0029 	PSNR: 26.3024	Accuracy: 65.756%
# Epoch 242 	Training Loss: 0.0029 	PSNR: 26.3082	Accuracy: 65.770%
# Epoch 243 	Training Loss: 0.0029 	PSNR: 26.2708	Accuracy: 65.677%
# Epoch 244 	Training Loss: 0.0029 	PSNR: 26.2797	Accuracy: 65.699%
# Epoch 245 	Training Loss: 0.0029 	PSNR: 26.2214	Accuracy: 65.553%
# Epoch 246 	Training Loss: 0.0029 	PSNR: 26.2207	Accuracy: 65.552%
# Epoch 247 	Training Loss: 0.0029 	PSNR: 26.2300	Accuracy: 65.575%
# Epoch 248 	Training Loss: 0.0029 	PSNR: 26.4093	Accuracy: 66.023%
# Epoch 249 	Training Loss: 0.0029 	PSNR: 26.2851	Accuracy: 65.713%
# Epoch 250 	Training Loss: 0.0031 	PSNR: 26.0868	Accuracy: 65.217%
# Epoch 251 	Training Loss: 0.0029 	PSNR: 26.1041	Accuracy: 65.260%
# Epoch 252 	Training Loss: 0.0029 	PSNR: 26.2888	Accuracy: 65.722%
# Epoch 253 	Training Loss: 0.0029 	PSNR: 26.4498	Accuracy: 66.125%
# Epoch 254 	Training Loss: 0.0029 	PSNR: 26.3116	Accuracy: 65.779%
# Epoch 255 	Training Loss: 0.0029 	PSNR: 26.3303	Accuracy: 65.826%
# Epoch 256 	Training Loss: 0.0029 	PSNR: 26.3424	Accuracy: 65.856%
# Epoch 257 	Training Loss: 0.0029 	PSNR: 26.3205	Accuracy: 65.801%
# Epoch 258 	Training Loss: 0.0029 	PSNR: 26.1289	Accuracy: 65.322%
# Epoch 259 	Training Loss: 0.0029 	PSNR: 26.2063	Accuracy: 65.516%
# Epoch 260 	Training Loss: 0.0030 	PSNR: 25.9292	Accuracy: 64.823%
# Epoch 261 	Training Loss: 0.0029 	PSNR: 26.2871	Accuracy: 65.718%
# Epoch 262 	Training Loss: 0.0029 	PSNR: 26.4066	Accuracy: 66.016%
# Epoch 263 	Training Loss: 0.0029 	PSNR: 26.3716	Accuracy: 65.929%
# Epoch 264 	Training Loss: 0.0029 	PSNR: 26.2423	Accuracy: 65.606%
# Epoch 265 	Training Loss: 0.0029 	PSNR: 26.4048	Accuracy: 66.012%
# Epoch 266 	Training Loss: 0.0029 	PSNR: 26.1548	Accuracy: 65.387%
# Epoch 267 	Training Loss: 0.0029 	PSNR: 26.0993	Accuracy: 65.248%
# Epoch 268 	Training Loss: 0.0029 	PSNR: 26.2706	Accuracy: 65.676%
# Epoch 269 	Training Loss: 0.0029 	PSNR: 25.9445	Accuracy: 64.861%
# Epoch 270 	Training Loss: 0.0031 	PSNR: 26.1952	Accuracy: 65.488%
# Epoch 271 	Training Loss: 0.0029 	PSNR: 26.3324	Accuracy: 65.831%
# Epoch 272 	Training Loss: 0.0029 	PSNR: 26.2405	Accuracy: 65.601%
# Epoch 273 	Training Loss: 0.0029 	PSNR: 26.2943	Accuracy: 65.736%
# Epoch 274 	Training Loss: 0.0029 	PSNR: 26.2137	Accuracy: 65.534%
# Epoch 275 	Training Loss: 0.0029 	PSNR: 26.2879	Accuracy: 65.720%
# Epoch 276 	Training Loss: 0.0029 	PSNR: 26.3913	Accuracy: 65.978%
# Epoch 277 	Training Loss: 0.0029 	PSNR: 26.2849	Accuracy: 65.712%
# Epoch 278 	Training Loss: 0.0029 	PSNR: 26.2927	Accuracy: 65.732%
# Epoch 279 	Training Loss: 0.0029 	PSNR: 26.2177	Accuracy: 65.544%
# Epoch 280 	Training Loss: 0.0029 	PSNR: 26.2314	Accuracy: 65.578%
# Epoch 281 	Training Loss: 0.0029 	PSNR: 26.2915	Accuracy: 65.729%
# Epoch 282 	Training Loss: 0.0029 	PSNR: 26.0957	Accuracy: 65.239%
# Epoch 283 	Training Loss: 0.0030 	PSNR: 26.2494	Accuracy: 65.623%
# Epoch 284 	Training Loss: 0.0029 	PSNR: 26.1852	Accuracy: 65.463%
# Epoch 285 	Training Loss: 0.0029 	PSNR: 26.3102	Accuracy: 65.775%
# Epoch 286 	Training Loss: 0.0029 	PSNR: 26.2050	Accuracy: 65.512%
# Epoch 287 	Training Loss: 0.0029 	PSNR: 26.2344	Accuracy: 65.586%
# Epoch 288 	Training Loss: 0.0029 	PSNR: 26.2570	Accuracy: 65.643%
# Epoch 289 	Training Loss: 0.0029 	PSNR: 26.2446	Accuracy: 65.612%
# Epoch 290 	Training Loss: 0.0029 	PSNR: 26.2029	Accuracy: 65.507%
# Epoch 291 	Training Loss: 0.0029 	PSNR: 26.1550	Accuracy: 65.387%
# Epoch 292 	Training Loss: 0.0029 	PSNR: 26.0547	Accuracy: 65.137%
# Epoch 293 	Training Loss: 0.0029 	PSNR: 26.3012	Accuracy: 65.753%
# Epoch 294 	Training Loss: 0.0029 	PSNR: 26.2004	Accuracy: 65.501%
# Epoch 295 	Training Loss: 0.0029 	PSNR: 26.3976	Accuracy: 65.994%
# Epoch 296 	Training Loss: 0.0029 	PSNR: 26.1797	Accuracy: 65.449%
# Epoch 297 	Training Loss: 0.0029 	PSNR: 26.2236	Accuracy: 65.559%
# Epoch 298 	Training Loss: 0.0029 	PSNR: 26.1188	Accuracy: 65.297%
# Epoch 299 	Training Loss: 0.0029 	PSNR: 25.9954	Accuracy: 64.989%
# Epoch 300 	Training Loss: 0.0029 	PSNR: 26.3368	Accuracy: 65.842%
# Epoch 301 	Training Loss: 0.0029 	PSNR: 26.2045	Accuracy: 65.511%
# Epoch 302 	Training Loss: 0.0029 	PSNR: 26.3091	Accuracy: 65.773%
# Epoch 303 	Training Loss: 0.0029 	PSNR: 26.1773	Accuracy: 65.443%
# Epoch 304 	Training Loss: 0.0029 	PSNR: 26.3187	Accuracy: 65.797%
# Epoch 305 	Training Loss: 0.0029 	PSNR: 26.1997	Accuracy: 65.499%
# Epoch 306 	Training Loss: 0.0028 	PSNR: 26.2582	Accuracy: 65.646%
# Epoch 307 	Training Loss: 0.0029 	PSNR: 26.4653	Accuracy: 66.163%
# Epoch 308 	Training Loss: 0.0028 	PSNR: 26.1780	Accuracy: 65.445%
# Epoch 309 	Training Loss: 0.0028 	PSNR: 26.2337	Accuracy: 65.584%
# Epoch 310 	Training Loss: 0.0028 	PSNR: 26.2679	Accuracy: 65.670%
# Epoch 311 	Training Loss: 0.0028 	PSNR: 26.1150	Accuracy: 65.287%
# Epoch 312 	Training Loss: 0.0029 	PSNR: 25.6057	Accuracy: 64.014%
# Epoch 313 	Training Loss: 0.0029 	PSNR: 26.1462	Accuracy: 65.366%
# Epoch 314 	Training Loss: 0.0029 	PSNR: 26.1314	Accuracy: 65.329%
# Epoch 315 	Training Loss: 0.0029 	PSNR: 26.3070	Accuracy: 65.768%
# Epoch 316 	Training Loss: 0.0028 	PSNR: 26.2553	Accuracy: 65.638%
# Epoch 317 	Training Loss: 0.0029 	PSNR: 25.3259	Accuracy: 63.315%
# Epoch 318 	Training Loss: 0.0029 	PSNR: 26.2128	Accuracy: 65.532%
# Epoch 319 	Training Loss: 0.0028 	PSNR: 26.1898	Accuracy: 65.475%
# Epoch 320 	Training Loss: 0.0028 	PSNR: 26.3510	Accuracy: 65.878%
# Epoch 321 	Training Loss: 0.0028 	PSNR: 26.1938	Accuracy: 65.485%
# Epoch 322 	Training Loss: 0.0028 	PSNR: 26.2562	Accuracy: 65.640%
# Epoch 323 	Training Loss: 0.0028 	PSNR: 26.2414	Accuracy: 65.604%
# Epoch 324 	Training Loss: 0.0028 	PSNR: 26.1857	Accuracy: 65.464%
# Epoch 325 	Training Loss: 0.0029 	PSNR: 26.2027	Accuracy: 65.507%
# Epoch 326 	Training Loss: 0.0029 	PSNR: 26.2924	Accuracy: 65.731%
# Epoch 327 	Training Loss: 0.0028 	PSNR: 26.2034	Accuracy: 65.509%
# Epoch 328 	Training Loss: 0.0028 	PSNR: 26.2306	Accuracy: 65.577%
# Epoch 329 	Training Loss: 0.0028 	PSNR: 26.2309	Accuracy: 65.577%
# Epoch 330 	Training Loss: 0.0028 	PSNR: 26.2260	Accuracy: 65.565%
# Epoch 331 	Training Loss: 0.0028 	PSNR: 26.2509	Accuracy: 65.627%
# Epoch 332 	Training Loss: 0.0028 	PSNR: 26.2240	Accuracy: 65.560%
# Epoch 333 	Training Loss: 0.0028 	PSNR: 26.2498	Accuracy: 65.624%
# Epoch 334 	Training Loss: 0.0029 	PSNR: 26.1807	Accuracy: 65.452%
# Epoch 335 	Training Loss: 0.0030 	PSNR: 26.3647	Accuracy: 65.912%
# Epoch 336 	Training Loss: 0.0028 	PSNR: 26.2106	Accuracy: 65.526%
# Epoch 337 	Training Loss: 0.0028 	PSNR: 26.2812	Accuracy: 65.703%
# Epoch 338 	Training Loss: 0.0028 	PSNR: 26.3838	Accuracy: 65.959%
# Epoch 339 	Training Loss: 0.0028 	PSNR: 26.2768	Accuracy: 65.692%
# Epoch 340 	Training Loss: 0.0028 	PSNR: 26.2103	Accuracy: 65.526%
# Epoch 341 	Training Loss: 0.0028 	PSNR: 26.2842	Accuracy: 65.710%
# Epoch 342 	Training Loss: 0.0028 	PSNR: 26.2421	Accuracy: 65.605%
# Epoch 343 	Training Loss: 0.0029 	PSNR: 26.3088	Accuracy: 65.772%
# Epoch 344 	Training Loss: 0.0028 	PSNR: 26.2092	Accuracy: 65.523%
# Epoch 345 	Training Loss: 0.0028 	PSNR: 26.2026	Accuracy: 65.506%
# Epoch 346 	Training Loss: 0.0028 	PSNR: 26.2072	Accuracy: 65.518%
# Epoch 347 	Training Loss: 0.0028 	PSNR: 26.2996	Accuracy: 65.749%
# Epoch 348 	Training Loss: 0.0028 	PSNR: 26.1907	Accuracy: 65.477%
# Epoch 349 	Training Loss: 0.0028 	PSNR: 26.2175	Accuracy: 65.544%
# Epoch 350 	Training Loss: 0.0028 	PSNR: 26.2181	Accuracy: 65.545%
# Epoch 351 	Training Loss: 0.0028 	PSNR: 26.2382	Accuracy: 65.595%
# Epoch 352 	Training Loss: 0.0028 	PSNR: 26.1551	Accuracy: 65.388%
# Epoch 353 	Training Loss: 0.0028 	PSNR: 26.3442	Accuracy: 65.860%
# Epoch 354 	Training Loss: 0.0029 	PSNR: 26.2505	Accuracy: 65.626%
# Epoch 355 	Training Loss: 0.0028 	PSNR: 26.3874	Accuracy: 65.969%
# Epoch 356 	Training Loss: 0.0028 	PSNR: 26.1675	Accuracy: 65.419%
# Epoch 357 	Training Loss: 0.0028 	PSNR: 26.5823	Accuracy: 66.456%
# Epoch 358 	Training Loss: 0.0028 	PSNR: 26.1857	Accuracy: 65.464%
# Epoch 359 	Training Loss: 0.0033 	PSNR: 24.7915	Accuracy: 61.979%
# Epoch 360 	Training Loss: 0.0031 	PSNR: 26.1477	Accuracy: 65.369%
# Epoch 361 	Training Loss: 0.0029 	PSNR: 26.2642	Accuracy: 65.661%
# Epoch 362 	Training Loss: 0.0028 	PSNR: 26.2012	Accuracy: 65.503%
# Epoch 363 	Training Loss: 0.0028 	PSNR: 26.1723	Accuracy: 65.431%
# Epoch 364 	Training Loss: 0.0028 	PSNR: 26.4192	Accuracy: 66.048%
# Epoch 365 	Training Loss: 0.0028 	PSNR: 26.1600	Accuracy: 65.400%
# Epoch 366 	Training Loss: 0.0028 	PSNR: 26.1975	Accuracy: 65.494%
# Epoch 367 	Training Loss: 0.0028 	PSNR: 26.2071	Accuracy: 65.518%
# Epoch 368 	Training Loss: 0.0028 	PSNR: 26.1367	Accuracy: 65.342%
# Epoch 369 	Training Loss: 0.0028 	PSNR: 26.3186	Accuracy: 65.796%
# Epoch 370 	Training Loss: 0.0028 	PSNR: 26.3019	Accuracy: 65.755%
# Epoch 371 	Training Loss: 0.0028 	PSNR: 26.2436	Accuracy: 65.609%
# Epoch 372 	Training Loss: 0.0028 	PSNR: 26.2761	Accuracy: 65.690%
# Epoch 373 	Training Loss: 0.0028 	PSNR: 26.3011	Accuracy: 65.753%
# Epoch 374 	Training Loss: 0.0028 	PSNR: 26.2835	Accuracy: 65.709%
# Epoch 375 	Training Loss: 0.0028 	PSNR: 26.1713	Accuracy: 65.428%
# Epoch 376 	Training Loss: 0.0028 	PSNR: 26.2411	Accuracy: 65.603%
# Epoch 377 	Training Loss: 0.0028 	PSNR: 26.2467	Accuracy: 65.617%
# Epoch 378 	Training Loss: 0.0028 	PSNR: 26.1843	Accuracy: 65.461%
# Epoch 379 	Training Loss: 0.0028 	PSNR: 26.3692	Accuracy: 65.923%
# Epoch 380 	Training Loss: 0.0028 	PSNR: 26.1524	Accuracy: 65.381%
# Epoch 381 	Training Loss: 0.0028 	PSNR: 26.2087	Accuracy: 65.522%
# Epoch 382 	Training Loss: 0.0028 	PSNR: 26.1974	Accuracy: 65.494%
# Epoch 383 	Training Loss: 0.0028 	PSNR: 26.1748	Accuracy: 65.437%
# Epoch 384 	Training Loss: 0.0028 	PSNR: 26.3225	Accuracy: 65.806%
# Epoch 385 	Training Loss: 0.0028 	PSNR: 26.2397	Accuracy: 65.599%
# Epoch 386 	Training Loss: 0.0028 	PSNR: 26.3047	Accuracy: 65.762%
# Epoch 387 	Training Loss: 0.0028 	PSNR: 26.1825	Accuracy: 65.456%
# Epoch 388 	Training Loss: 0.0028 	PSNR: 26.2186	Accuracy: 65.546%
# Epoch 389 	Training Loss: 0.0028 	PSNR: 26.2202	Accuracy: 65.550%
# Epoch 390 	Training Loss: 0.0028 	PSNR: 26.2735	Accuracy: 65.684%
# Epoch 391 	Training Loss: 0.0028 	PSNR: 26.3554	Accuracy: 65.889%
# Epoch 392 	Training Loss: 0.0028 	PSNR: 26.1684	Accuracy: 65.421%
# Epoch 393 	Training Loss: 0.0028 	PSNR: 26.3203	Accuracy: 65.801%
# Epoch 394 	Training Loss: 0.0028 	PSNR: 26.3097	Accuracy: 65.774%
# Epoch 395 	Training Loss: 0.0028 	PSNR: 26.2888	Accuracy: 65.722%
# Epoch 396 	Training Loss: 0.0029 	PSNR: 26.0588	Accuracy: 65.147%
# Epoch 397 	Training Loss: 0.0028 	PSNR: 26.1836	Accuracy: 65.459%
# Epoch 398 	Training Loss: 0.0028 	PSNR: 26.2604	Accuracy: 65.651%
# Epoch 399 	Training Loss: 0.0028 	PSNR: 26.1204	Accuracy: 65.301%
# Epoch 400 	Training Loss: 0.0028 	PSNR: 26.1920	Accuracy: 65.480%
# Epoch 401 	Training Loss: 0.0028 	PSNR: 26.3705	Accuracy: 65.926%
# Epoch 402 	Training Loss: 0.0028 	PSNR: 26.2701	Accuracy: 65.675%
# Epoch 403 	Training Loss: 0.0028 	PSNR: 26.1586	Accuracy: 65.396%
# Epoch 404 	Training Loss: 0.0028 	PSNR: 26.1341	Accuracy: 65.335%
# Epoch 405 	Training Loss: 0.0028 	PSNR: 26.2235	Accuracy: 65.559%
# Epoch 406 	Training Loss: 0.0028 	PSNR: 26.1098	Accuracy: 65.274%
# Epoch 407 	Training Loss: 0.0029 	PSNR: 26.1800	Accuracy: 65.450%
# Epoch 408 	Training Loss: 0.0028 	PSNR: 26.3594	Accuracy: 65.899%
# Epoch 409 	Training Loss: 0.0028 	PSNR: 26.2894	Accuracy: 65.724%
# Epoch 410 	Training Loss: 0.0028 	PSNR: 26.3453	Accuracy: 65.863%
# Epoch 411 	Training Loss: 0.0028 	PSNR: 26.2374	Accuracy: 65.594%
# Epoch 412 	Training Loss: 0.0028 	PSNR: 26.4246	Accuracy: 66.062%
# Epoch 413 	Training Loss: 0.0028 	PSNR: 26.2415	Accuracy: 65.604%
# Epoch 414 	Training Loss: 0.0028 	PSNR: 26.2297	Accuracy: 65.574%
# Epoch 415 	Training Loss: 0.0028 	PSNR: 26.2067	Accuracy: 65.517%
# Epoch 416 	Training Loss: 0.0028 	PSNR: 26.1856	Accuracy: 65.464%
# Epoch 417 	Training Loss: 0.0028 	PSNR: 26.2667	Accuracy: 65.667%
# Epoch 418 	Training Loss: 0.0028 	PSNR: 26.2879	Accuracy: 65.720%
# Epoch 419 	Training Loss: 0.0028 	PSNR: 26.2651	Accuracy: 65.663%
# Epoch 420 	Training Loss: 0.0028 	PSNR: 26.1747	Accuracy: 65.437%
# Epoch 421 	Training Loss: 0.0028 	PSNR: 26.1359	Accuracy: 65.340%
# Epoch 422 	Training Loss: 0.0028 	PSNR: 26.1259	Accuracy: 65.315%
# Epoch 423 	Training Loss: 0.0028 	PSNR: 26.3106	Accuracy: 65.776%
# Epoch 424 	Training Loss: 0.0028 	PSNR: 26.3531	Accuracy: 65.883%
# Epoch 425 	Training Loss: 0.0028 	PSNR: 26.2171	Accuracy: 65.543%
# Epoch 426 	Training Loss: 0.0028 	PSNR: 26.3808	Accuracy: 65.952%
# Epoch 427 	Training Loss: 0.0028 	PSNR: 26.1813	Accuracy: 65.453%
# Epoch 428 	Training Loss: 0.0028 	PSNR: 26.1096	Accuracy: 65.274%
# Epoch 429 	Training Loss: 0.0028 	PSNR: 26.2472	Accuracy: 65.618%
# Epoch 430 	Training Loss: 0.0028 	PSNR: 26.1812	Accuracy: 65.453%
# Epoch 431 	Training Loss: 0.0028 	PSNR: 26.3074	Accuracy: 65.768%
# Epoch 432 	Training Loss: 0.0028 	PSNR: 26.3213	Accuracy: 65.803%
# Epoch 433 	Training Loss: 0.0028 	PSNR: 26.3573	Accuracy: 65.893%
# Epoch 434 	Training Loss: 0.0028 	PSNR: 26.0317	Accuracy: 65.079%
# Epoch 435 	Training Loss: 0.0028 	PSNR: 26.3345	Accuracy: 65.836%
# Epoch 436 	Training Loss: 0.0028 	PSNR: 26.3440	Accuracy: 65.860%
# Epoch 437 	Training Loss: 0.0028 	PSNR: 26.2983	Accuracy: 65.746%
# Epoch 438 	Training Loss: 0.0028 	PSNR: 26.3213	Accuracy: 65.803%
# Epoch 439 	Training Loss: 0.0028 	PSNR: 26.2984	Accuracy: 65.746%
# Epoch 440 	Training Loss: 0.0028 	PSNR: 26.2045	Accuracy: 65.511%
# Epoch 441 	Training Loss: 0.0029 	PSNR: 25.9565	Accuracy: 64.891%
# Epoch 442 	Training Loss: 0.0028 	PSNR: 26.2151	Accuracy: 65.538%
# Epoch 443 	Training Loss: 0.0028 	PSNR: 26.1697	Accuracy: 65.424%
# Epoch 444 	Training Loss: 0.0028 	PSNR: 26.1620	Accuracy: 65.405%
# Epoch 445 	Training Loss: 0.0028 	PSNR: 26.2477	Accuracy: 65.619%
# Epoch 446 	Training Loss: 0.0028 	PSNR: 26.2324	Accuracy: 65.581%
# Epoch 447 	Training Loss: 0.0028 	PSNR: 26.1117	Accuracy: 65.279%
# Epoch 448 	Training Loss: 0.0029 	PSNR: 26.1744	Accuracy: 65.436%
# Epoch 449 	Training Loss: 0.0028 	PSNR: 26.1711	Accuracy: 65.428%
# Epoch 450 	Training Loss: 0.0028 	PSNR: 26.2834	Accuracy: 65.708%
# Epoch 451 	Training Loss: 0.0028 	PSNR: 26.1583	Accuracy: 65.396%
# Epoch 452 	Training Loss: 0.0028 	PSNR: 26.3096	Accuracy: 65.774%
# Epoch 453 	Training Loss: 0.0028 	PSNR: 26.2812	Accuracy: 65.703%
# Epoch 454 	Training Loss: 0.0028 	PSNR: 26.2202	Accuracy: 65.550%
# Epoch 455 	Training Loss: 0.0028 	PSNR: 26.4393	Accuracy: 66.098%
# Epoch 456 	Training Loss: 0.0028 	PSNR: 26.2148	Accuracy: 65.537%
# Epoch 457 	Training Loss: 0.0028 	PSNR: 26.2134	Accuracy: 65.533%
# Epoch 458 	Training Loss: 0.0028 	PSNR: 26.1289	Accuracy: 65.322%
# Epoch 459 	Training Loss: 0.0028 	PSNR: 26.2048	Accuracy: 65.512%
# Epoch 460 	Training Loss: 0.0028 	PSNR: 26.2647	Accuracy: 65.662%
# Epoch 461 	Training Loss: 0.0028 	PSNR: 26.1679	Accuracy: 65.420%
# Epoch 462 	Training Loss: 0.0028 	PSNR: 26.1862	Accuracy: 65.465%
# Epoch 463 	Training Loss: 0.0028 	PSNR: 26.0838	Accuracy: 65.210%
# Epoch 464 	Training Loss: 0.0028 	PSNR: 26.2480	Accuracy: 65.620%
# Epoch 465 	Training Loss: 0.0028 	PSNR: 26.2003	Accuracy: 65.501%
# Epoch 466 	Training Loss: 0.0028 	PSNR: 26.2997	Accuracy: 65.749%
# Epoch 467 	Training Loss: 0.0028 	PSNR: 26.0272	Accuracy: 65.068%
# Epoch 468 	Training Loss: 0.0028 	PSNR: 26.0784	Accuracy: 65.196%
# Epoch 469 	Training Loss: 0.0028 	PSNR: 26.2605	Accuracy: 65.651%
# Epoch 470 	Training Loss: 0.0028 	PSNR: 26.3128	Accuracy: 65.782%
# Epoch 471 	Training Loss: 0.0028 	PSNR: 26.2971	Accuracy: 65.743%
# Epoch 472 	Training Loss: 0.0028 	PSNR: 26.2494	Accuracy: 65.623%
# Epoch 473 	Training Loss: 0.0028 	PSNR: 26.1298	Accuracy: 65.324%
# Epoch 474 	Training Loss: 0.0028 	PSNR: 26.2121	Accuracy: 65.530%
# Epoch 475 	Training Loss: 0.0028 	PSNR: 26.1752	Accuracy: 65.438%
# Epoch 476 	Training Loss: 0.0028 	PSNR: 26.1198	Accuracy: 65.299%
# Epoch 477 	Training Loss: 0.0028 	PSNR: 26.3217	Accuracy: 65.804%
# Epoch 478 	Training Loss: 0.0028 	PSNR: 26.2485	Accuracy: 65.621%
# Epoch 479 	Training Loss: 0.0028 	PSNR: 26.2991	Accuracy: 65.748%
# Epoch 480 	Training Loss: 0.0028 	PSNR: 26.0006	Accuracy: 65.002%
# Epoch 481 	Training Loss: 0.0028 	PSNR: 26.3124	Accuracy: 65.781%
# Epoch 482 	Training Loss: 0.0028 	PSNR: 26.1072	Accuracy: 65.268%
# Epoch 483 	Training Loss: 0.0028 	PSNR: 25.9897	Accuracy: 64.974%
# Epoch 484 	Training Loss: 0.0028 	PSNR: 26.1815	Accuracy: 65.454%
# Epoch 485 	Training Loss: 0.0028 	PSNR: 26.1952	Accuracy: 65.488%
# Epoch 486 	Training Loss: 0.0028 	PSNR: 26.1907	Accuracy: 65.477%
# Epoch 487 	Training Loss: 0.0028 	PSNR: 26.3311	Accuracy: 65.828%
# Epoch 488 	Training Loss: 0.0028 	PSNR: 26.1783	Accuracy: 65.446%
# Epoch 489 	Training Loss: 0.0028 	PSNR: 26.1775	Accuracy: 65.444%
# Epoch 490 	Training Loss: 0.0028 	PSNR: 26.2194	Accuracy: 65.549%
# Epoch 491 	Training Loss: 0.0028 	PSNR: 26.1844	Accuracy: 65.461%
# Epoch 492 	Training Loss: 0.0028 	PSNR: 26.2042	Accuracy: 65.510%
# Epoch 493 	Training Loss: 0.0028 	PSNR: 26.4175	Accuracy: 66.044%
# Epoch 494 	Training Loss: 0.0028 	PSNR: 26.2178	Accuracy: 65.545%
# Epoch 495 	Training Loss: 0.0028 	PSNR: 26.0773	Accuracy: 65.193%
# Epoch 496 	Training Loss: 0.0028 	PSNR: 26.0954	Accuracy: 65.239%
# Epoch 497 	Training Loss: 0.0028 	PSNR: 26.1873	Accuracy: 65.468%
# Epoch 498 	Training Loss: 0.0028 	PSNR: 26.1313	Accuracy: 65.328%
# Epoch 499 	Training Loss: 0.0028 	PSNR: 26.1380	Accuracy: 65.345%
# Epoch 500 	Training Loss: 0.0028 	PSNR: 26.1461	Accuracy: 65.365%

# %%
model_out_path = "model_epoch.pth".format(epoch)
torch.save(model,model_out_path)
print("Checkpoint saved to".format(model_out_path))
# Out:
# Checkpoint saved to
# D:\Anaconda\lib\site-packages\torch\serialization.py:250: UserWarning: Couldn't retrieve source code for container of type Model. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
